# %%
import pandas as pd
from Univariate import Univariate
univariateObj=Univariate()
dataset=pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
quan,qual=univariateObj.quanQual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
univariateObj.createDescriptiveTable(dataset)
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0      91.86      83.86       97.0    76.1142
# Q4:100%   215.0       89.4       97.7       91.0       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %%
datasetWithoutOutLier=pd.read_csv("Placement.csv")
lesser,greater=univariateObj.getOutliers(datasetWithoutOutLier)

# %%
lesser
# Out:
# ['hsc_p']

# %%
greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
univariateObj.removeOutlier(datasetWithoutOutLier)
lesser,greater=univariateObj.getOutliers(datasetWithoutOutLier)
univariateObj.createFrequencyTable("ssc_p",dataset)
# Out:
# C:\GITCHECKOUT\Frequency\Univariate.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[columnName][dataset[columnName]<descriptive[columnName]["Lesser"]]=descriptive[columnName]["Lesser"]
# C:\GITCHECKOUT\Frequency\Univariate.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[columnName][dataset[columnName]>descriptive[columnName]["Greater"]]=descriptive[columnName]["Greater"]
# C:\GITCHECKOUT\Frequency\Univariate.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %%
univariateObj.createFrequencyTable("ssc_p",dataset)
# Out:
#      Unique_values  Frequency  Relative_Frequency    Cumsum
# 0            62.00         11            0.106796  0.106796
# 1            63.00         10            0.097087  0.203883
# 2            67.00          9            0.087379  0.291262
# 3            52.00          9            0.087379  0.378641
# 4            73.00          9            0.087379  0.466019
# ..             ...        ...                 ...       ...
# 98           69.70          1            0.009709  2.048544
# 99           80.92          1            0.009709  2.058252
# 100          83.00          1            0.009709  2.067961
# 101          86.50          1            0.009709  2.077670
# 102          80.60          1            0.009709  2.087379
#
# [103 rows x 4 columns]

# %%
univariateObj.createFrequencyTable("hsc_p",dataset)
# Out:
#     Unique_values  Frequency  Relative_Frequency    Cumsum
# 0           63.00         14            0.135922  0.135922
# 1           62.00         12            0.116505  0.252427
# 2           67.00          9            0.087379  0.339806
# 3           60.00          9            0.087379  0.427184
# 4           64.00          8            0.077670  0.504854
# ..            ...        ...                 ...       ...
# 92          83.83          1            0.009709  2.048544
# 93          70.40          1            0.009709  2.058252
# 94          90.90          1            0.009709  2.067961
# 95          89.83          1            0.009709  2.077670
# 96          42.00          1            0.009709  2.087379
#
# [97 rows x 4 columns]

# %%
univariateObj.createFrequencyTable("degree_p",dataset)
# Out:
#     Unique_values  Frequency  Relative_Frequency    Cumsum
# 0            65.0         20            0.194175  0.194175
# 1            66.0         13            0.126214  0.320388
# 2            72.0         12            0.116505  0.436893
# 3            64.0         11            0.106796  0.543689
# 4            58.0          9            0.087379  0.631068
# ..            ...        ...                 ...       ...
# 84           82.0          1            0.009709  2.048544
# 85           50.8          1            0.009709  2.058252
# 86           76.0          1            0.009709  2.067961
# 87           63.0          1            0.009709  2.077670
# 88           77.6          1            0.009709  2.087379
#
# [89 rows x 4 columns]

# %%
univariateObj.createFrequencyTable("ssc_p",dataset)
# Out:
#      Unique_values  Frequency  Relative_Frequency    Cumsum
# 0            62.00         11            0.106796  0.106796
# 1            63.00         10            0.097087  0.203883
# 2            67.00          9            0.087379  0.291262
# 3            52.00          9            0.087379  0.378641
# 4            73.00          9            0.087379  0.466019
# ..             ...        ...                 ...       ...
# 98           69.70          1            0.009709  2.048544
# 99           80.92          1            0.009709  2.058252
# 100          83.00          1            0.009709  2.067961
# 101          86.50          1            0.009709  2.077670
# 102          80.60          1            0.009709  2.087379
#
# [103 rows x 4 columns]

# %%
univariateObj.createFrequencyTable("etest_p",dataset)
# Out:
#     Unique_values  Frequency  Relative_Frequency    Cumsum
# 0           60.00         14            0.135922  0.135922
# 1           80.00          8            0.077670  0.213592
# 2           75.00          7            0.067961  0.281553
# 3           67.00          7            0.067961  0.349515
# 4           55.00          6            0.058252  0.407767
# ..            ...        ...                 ...       ...
# 95          95.46          1            0.009709  2.048544
# 96          93.91          1            0.009709  2.058252
# 97          56.39          1            0.009709  2.067961
# 98          57.50          1            0.009709  2.077670
# 99          91.00          1            0.009709  2.087379
#
# [100 rows x 4 columns]

# %%
univariateObj.createFrequencyTable("mba_p",dataset)
# Out:
#      Unique_values  Frequency  Relative_Frequency    Cumsum
# 0            56.70          3            0.029126  0.029126
# 1            66.94          2            0.019417  0.048544
# 2            59.47          2            0.019417  0.067961
# 3            60.44          2            0.019417  0.087379
# 4            68.07          2            0.019417  0.106796
# ..             ...        ...                 ...       ...
# 200          67.00          1            0.009709  2.048544
# 201          64.27          1            0.009709  2.058252
# 202          57.65          1            0.009709  2.067961
# 203          59.42          1            0.009709  2.077670
# 204          60.22          1            0.009709  2.087379
#
# [205 rows x 4 columns]

# %%
univariateObj.createFrequencyTable("salary",dataset)
# Out:
#     Unique_values  Frequency  Relative_Frequency    Cumsum
# 0        300000.0         22            0.213592  0.213592
# 1        250000.0         18            0.174757  0.388350
# 2        240000.0         15            0.145631  0.533981
# 3        260000.0          7            0.067961  0.601942
# 4        360000.0          6            0.058252  0.660194
# 5        200000.0          6            0.058252  0.718447
# 6        265000.0          6            0.058252  0.776699
# 7        220000.0          5            0.048544  0.825243
# 8        275000.0          5            0.048544  0.873786
# 9        210000.0          4            0.038835  0.912621
# 10       400000.0          4            0.038835  0.951456
# 11       270000.0          4            0.038835  0.990291
# 12       216000.0          3            0.029126  1.019417
# 13       350000.0          3            0.029126  1.048544
# 14       500000.0          3            0.029126  1.077670
# ...
